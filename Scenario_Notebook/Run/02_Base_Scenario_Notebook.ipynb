# %%
import os
from pathlib import Path
import subprocess
import matplotlib.pyplot as plt
import pyemu
import flopy
import warnings
warnings.filterwarnings(action='ignore')
import pandas as pd
import geopandas as gpd
import numpy as np
from IPython.display import display
import time
import psutil

# %%
#set variables used below
cwd = os.getcwd()
pardir = os.pardir
base_model_dir = Path('../../Base_Model_for_Scenarios').resolve()
obs_locs_dir =  Path('../../Locations/Obs_locs').resolve()
truth_model_riv_obs_results = '../../Refined_Truth_Model/Modflow_Input_Files/riv_obs.csv'                         
print(cwd)
print(pardir)
print(base_model_dir)
print(obs_locs_dir)
# Out:
# C:\Users\farnut1\Desktop\How-Many-Realizations-main\Scenario_Notebook\run
# ..
# C:\Users\farnut1\Desktop\How-Many-Realizations-main\Base_Model_for_Scenarios
# C:\Users\farnut1\Desktop\How-Many-Realizations-main\Locations\Obs_locs

# %%
# Get number of physical cores, minus 2.
num_workers = psutil.cpu_count(logical=False)
print(num_workers)
# Out:
# 20

# %% [markdown]
# ### Inputs

# %%
# Loops through all scenarios
# 12 possible scenario groups
for Group in range(1,13):#13):
    print(Group)

    num_reals_list = [10, 25, 50, 100, 250, 500, 1000, 2000]
    #num_reals_list = [10, 50]  # For testing purposes
    
    obs_locsR25 =  obs_locs_dir / 'R25.csv'
    obs_locsR100 = obs_locs_dir / 'R100.csv'
    obs_locsC25 = obs_locs_dir / 'C25.csv'
    obs_locsC100 = obs_locs_dir / 'C100.csv'

    if Group == 1:
        gname = 'R25_pp10'
        obs_locs = obs_locsR25
        pp_space = 10
    if Group == 2:
        gname = 'R100_pp10'
        obs_locs = obs_locsR100
        pp_space = 10
    if Group == 3:
        gname = 'C25_pp10'
        obs_locs = obs_locsC25
        pp_space = 10
    if Group == 4:
        gname = 'C100_pp10'
        obs_locs = obs_locsC100
        pp_space = 10
    if Group == 5:
        gname = 'R25_pp25'
        obs_locs = obs_locsR25
        pp_space = 25
    if Group == 6:
        gname = 'R100_pp25'
        obs_locs = obs_locsR100
        pp_space = 25
    if Group == 7:
        gname = 'C25_pp25'
        obs_locs = obs_locsC25
        pp_space = 25
    if Group == 8:
        gname = 'C100_pp25'
        obs_locs = obs_locsC100
        pp_space = 25
    if Group == 9:    
        gname = 'R25_pp50'
        obs_locs = obs_locsR25
        pp_space = 50
    if Group == 10:
        gname = 'R100_pp50'
        obs_locs = obs_locsR100
        pp_space = 50
    if Group == 11:
        gname = 'C25_pp50'
        obs_locs = obs_locsC25
        pp_space = 50
    if Group == 12:
        gname = 'C100_pp50'
        obs_locs = obs_locsC100
        pp_space = 50

    for num_real_val in num_reals_list:
        num_reals=num_real_val
        print(num_reals)
    
        # specify a template directory (i.e. the PstFrom working folder)
        scenario_ws = os.path.join(pardir,f'{gname}'+"_real"+ f'{num_reals}')
        os.makedirs(scenario_ws, exist_ok=True)
        template_ws = os.path.join(cwd,'template_d')
    
        # Read in obs and pp locs, turn to dataframe
        obs_locs_df = pd.read_csv(obs_locs)
        
        # convert to geodataframe
        obs_locs_df = gpd.GeoDataFrame(obs_locs_df, geometry=gpd.points_from_xy(obs_locs_df['x'], obs_locs_df['y']), crs = 'EPSG:26915')
        
        # Get model_root_name from listing file
        for file in os.listdir(base_model_dir):
            if file.endswith(".dis"):
                disfile = file
        model_name = os.path.splitext(disfile)[0]
        print(model_name)
    
        sim = flopy.mf6.MFSimulation.load(f'{model_name}', sim_ws=base_model_dir, exe_name='mf6.exe')
        sim.set_sim_path(cwd)
        model = sim.get_model(f'{model_name}')
    
        # Intersect observations with the grid to get cellid
        ix = flopy.utils.gridintersect.GridIntersect(model.modelgrid, method="vertex", rtree=True)
        
        obs_cells = []
        for g in obs_locs_df.geometry:
            v = ix.intersect(g)
            obs_cells.append((0, v['cellids'][0][0].item(), v['cellids'][0][1].item()))
        
        # Add cell id to dataframe
        obs_locs_df['cellid'] = obs_cells
        
        # Add obsname column
        # this should already have been added by Export_Heads_Capture_flows.ipynb
        #obs_locs_df = obs_locs_df.reset_index()
        #obs_locs_df = obs_locs_df.rename(columns={'index':'obsname'})
        #obs_locs_df['obsname'] +=1
        #obs_locs_df['obsname'] = 'o' + obs_locs_df['obsname'].astype(str)
        obs_locs_df['obsname'] = obs_locs_df['site_name']
        
        # Add head column
        obs_locs_df['obstype'] = 'head'
        
        # Make new df for obs package
        obs_package_df = obs_locs_df[['obsname','obstype','cellid']]
        
        # Turn to recarray
        obs_package_data = obs_package_df.to_records(index=False)
        
        obs_recarray = {'head_obs.csv': obs_package_data}
    
        # Add head obs to model
        gwfobs = flopy.mf6.ModflowUtlobs(model, continuous=obs_recarray, filename=f'{model_name}.obs', pname='gwfobs_0')
    
        # Add riv flux obs to model
        # first add a boundname to the stress period data
        riv_spd = {0: model.riv.stress_period_data.data[0]}
        #temporarily recast to dataframe because recarrays are too hard to work with
        riv_spd[0] = pd.DataFrame(riv_spd[0])
        riv_spd[0]['boundname'] = 'river'
        # update the conductance to be more like the truth model as well
        riv_spd[0]['cond'] = 250
        riv_spd[0] = riv_spd[0].to_records(index=False)
        # input to the MODFLOW for RIV observations
        riv_obs = pd.DataFrame({
            'obsname': ['riv-flux'],
            'type': ['riv'],
            'id': ['river']  # the boundname that we made above; includes all RIV cells
        }).to_records(index=False)
        riv = flopy.mf6.modflow.mfgwfriv.ModflowGwfriv(
            model, save_flows=True, observations={'riv_obs.csv': riv_obs}, stress_period_data=riv_spd, boundnames=True,
            filename=f'{model.name}.riv', pname='riv_0')
        
        # edit GHB package conductance to be more like truth model
        ghb_spd = {0: model.ghb.stress_period_data.data[0]}
        #temporarily recast to dataframe because recarrays are too hard to work with
        ghb_spd[0] = pd.DataFrame(ghb_spd[0])
        # set GHB leakance at arbitrary large value of 1,000
        # (cond = leakance * area)
        ghb_spd[0]['cond'] = 1000 * 25**2  # assumes base model discretization of 25 units
        ghb_spd[0] = ghb_spd[0].to_records(index=False)
        ghb = flopy.mf6.modflow.mfgwfghb.ModflowGwfghb(
            model, save_flows=True, stress_period_data=ghb_spd,
            filename=f'{model.name}.ghb', pname='ghb_0')
        
        sim.simulation_data.max_columns_auto_set=False
        sim.simulation_data.max_columns_of_data=1
        sim.set_all_data_external()
        sim.write_simulation()
        sim.run_simulation()    
    
        # Pest Section
        # Inputs
        # external file with horizontal hydraulic conductivity values
        kh_array_file = f'{model_name}.npf_k.txt'
        # external file with recharge
        rcha_external_array_file = f'{model_name}.rcha_recharge_1.txt'
        # external file with riv conductance
        riv_external_file =f'{model_name}.riv_stress_period_data_1.txt'
        # external file with well flow rates
        wel_external_file = f'{model_name}.wel_stress_period_data_1.txt'
        
        # pestpp-ies settings
        ies_num_reals = num_reals
        pest_casename = model_name
        
        # Outputs
        template_ws = Path(f'{template_ws}')  # new model workspace folder created by pyEMU for the PEST run
        out_pst_file = template_ws / f"{pest_casename}.pst"
        
        model_grid_cell_spacing = model.modelgrid.delr[0].item()  # assuming a uniform grid    
    
        # Set up the PstFrom object
        pf = pyemu.utils.PstFrom(original_d=cwd, new_d=template_ws, remove_existing=True, longnames=True, spatial_reference=model.modelgrid,
                                 zero_based=False, tpl_subfolder='tpl')    
        
        # fix wrapped external array files
        for f in kh_array_file, rcha_external_array_file:
            wrapped_array = np.loadtxt(template_ws / f)
            reshaped_array = np.reshape(wrapped_array, model.modelgrid.shape[1:])
            np.savetxt(template_ws / f, reshaped_array)    
    
        # Add Head observations
        heads_df = pd.read_csv(template_ws / "head_obs.csv", index_col=0)
        pf.add_observations('head_obs.csv', insfile='head_obs.csv.ins', index_cols='time', use_cols=(list(heads_df.columns.values)), prefix='hds')
        # Add RIV observation
        riv_flux_df = pd.read_csv(template_ws / "riv_obs.csv", index_col=0)
        pf.add_observations('riv_obs.csv', insfile='riv_obs.csv.ins', index_cols='time', use_cols=['RIV-FLUX'], prefix='riv')
    
        # directly estimate a mean value for hydraulic conductivity across the model grid
        prop = 'kh'
        par_name_base = f"{prop}-mult-constant"
        pf.add_parameters(filenames=kh_array_file, par_type="constant",
                          par_name_base=par_name_base,
                          pargp=par_name_base, zone_array=None,
                          upper_bound=10,
                          lower_bound=0.1,
                          )    
    
        # set up horizontal hydraulic conductivity pilot points
        # Initial multiplier to apply to pilot points
        pp_parval1 = 1
        # set the upper and lower pilot point bounds
        # based on a desired number of log cycles
        # PEST++ or pyEMU will use the bounds to sample a log-normal distribution;
        # setting the bounds symetically ensures that the distribution will centered on parval1
        log_range = 3  # number of orders of magnitude between upper and lower pilot point bounds
        pp_lower_bound = 10**(np.log10(pp_parval1) - log_range/2)
        pp_upper_bound = 10**(np.log10(pp_parval1) + log_range/2)
        
        # geostructure for pilot points
        alpha = model_grid_cell_spacing * pp_space * 3
        v = pyemu.geostats.ExpVario(contribution=1.0, a=alpha)
        pp_gs = pyemu.geostats.GeoStruct(variograms=v, nugget=0, transform='log')
    
        # add pilot point parameters
        par_style = 'mult'  # only multipliers are supported for pilot points in pyEMU
        par_type = 'pilotpoints'
        par_name_base = f"{prop}-{par_style}-{par_type}"
        pf.add_parameters(
            filenames=f'{model_name}.npf_k.txt', 
            par_type=par_type, par_style=par_style,
            geostruct=pp_gs, pp_space=pp_space,    
            # all pilot points are in the same zone (with same geo-structure)
            zone_array=None, use_pp_zones=False,
            comment_char='#',  # comment indicator in model files
            par_name_base=par_name_base,  # basename for parameters that are set up
            pargp=par_name_base,  # Parameter group to assign pars to.
            # This is PESTs pargp but is also used to gather correlated parameters set up using multiple
            # add_parameters() calls (e.g. temporal pars) with common geostructs.
            lower_bound=pp_lower_bound, upper_bound=pp_upper_bound, 
            #ult_ubound=upper_bound,ult_lbound=lower_bound,
            )
    
        # Add a recharge multiplier
        prop = 'rech'
        par_name_base = f"{prop}-mult-constant"
        pf.add_parameters(filenames=rcha_external_array_file, par_type="constant",
                          par_name_base=par_name_base,
                          pargp=par_name_base, zone_array=None,
                          upper_bound=2., lower_bound=0.5
                          )
    
        # Parametrize River Package conductances
        par_name_base="rivcond-mult-constant"
        pf.add_parameters(filenames=riv_external_file, par_type="constant",
            par_name_base=par_name_base, pargp=par_name_base,
            upper_bound=10, lower_bound=0.1,
            index_cols={'i': 1, 'j': 2}, 
            use_cols=[4], # parametrize rates in the 4th column
            par_style="multiplier",
            comment_char='#')
    
        # Parametrize Well Package pumping rates
        par_name_base="wellrate-mult-constant"
        pf.add_parameters(filenames=wel_external_file, par_type="grid",
            par_name_base=par_name_base, pargp=par_name_base,
            upper_bound=1.2, lower_bound=0.8,
            index_cols={'i': 1, 'j': 2}, 
            use_cols=[3], # parametrize rates in the 4th column
            par_style="multiplier",
            comment_char='#')
    
        # Set up the PEST control dataset
        pst = pf.build_pst(f'{pest_casename}.pst')
        pardata = pst.parameter_data
    
        # Add 'observed' head values from 'truth' model
        obs_locs_df['obsnme'] = [f"oname:hds_otype:lst_usecol:{site_no}_time:1" for site_no in obs_locs_df['obsname']]
        obs_locs_df.index = obs_locs_df['obsnme']
        pst.observation_data['obsval'] = obs_locs_df['head']
        # Add noise to observation data of 0.25 meters
        pst.observation_data["standard_deviation"] = 0.25
        # 'observed' RIV flux
        riv_flux_truth_df = pd.read_csv(truth_model_riv_obs_results)
        riv_flux_truth = riv_flux_truth_df['RIV-FLUX'].values[0]
        pst.observation_data.loc['oname:riv_otype:lst_usecol:riv-flux_time:1', 'obsval'] = riv_flux_truth
        pst.observation_data.loc['oname:riv_otype:lst_usecol:riv-flux_time:1', 'standard_deviation'] =\
            np.abs(0.05 * riv_flux_truth)  # +/- 5% noise
        pst.observation_data.loc['oname:riv_otype:lst_usecol:riv-flux_time:1', 'weight'] =\
            1/np.abs(0.10 * riv_flux_truth)  # implies 10% std error
    
        # build spatial covariance
        # if you have more than about 35K pars, the cov matrix becomes hard to handle
        if pf.pst.npar < 35000: 
            cov = pf.build_prior(fmt='coo', filename=template_ws / "prior_cov.jcb")
            pst.pestpp_options["parcov"] = "prior_cov.jcb"
        
            # build the prior ensemble
            pe = pf.draw(num_reals=ies_num_reals, use_specsim=True, scale_offset=False) # draw parameters from the prior distribution
            pe.enforce() # enforces parameter bounds
            pe.to_binary(template_ws / "prior_pe.jcb")  #writes the paramter ensemble to binary file
            assert pe.shape[1] == np.sum(pardata.partrans != 'fixed')  
            pst.pestpp_options["ies_parameter_ensemble"] = "prior_pe.jcb"
    
        # pst options
        pst.control_data.noptmax = 4
        pst.pestpp_options["ies_num_reals"] = ies_num_reals
        pst.pestpp_options["ies_no_noise"] = "false"
        pst.pestpp_options["ies_bad_phi_sigma"] = 2.5
        #pst.pestpp_options['ies_save_binary'] = 'true'
        #pst.pestpp_options['ies_csv_by_reals'] = 'false'
    
        # write out PEST control file
        pf.pst.write(out_pst_file, version=2)
        print(f'wrote {out_pst_file}')
    
        # Add mf6 to forward run
        pf.mod_sys_cmds.append('mf6')
        pf.write_forward_run()
    
        # Run IES
        pyemu.os_utils.start_workers(template_ws, 'pestpp-ies', f'{model_name}.pst',
                                     num_workers=num_workers, worker_root=cwd, master_dir=scenario_ws)
# Out:
# 1
# 10
# fp_mf6_model
# loading simulation...
#   loading simulation name file...
#   loading tdis package...
#   loading model gwf6...
#     loading package dis...
#     loading package ic...
#     loading package riv...
#     loading package ghb...
#     loading package wel...
#     loading package rch...
#     loading package npf...
#     loading package oc...
#   loading solution package fp_mf6_model...
# WARNING: Package with name riv_0 already exists. Replacing existing package.
# WARNING: Package with name ghb_0 already exists. Replacing existing package.
# writing simulation...
#   writing simulation name file...
#   writing simulation tdis package...
#   writing solution package fp_mf6_model...
#   writing model fp_mf6_model...
#     writing model name file...
#     writing package dis...
#     writing package ic...
#     writing package wel_0...
#     writing package rcha_0...
#     writing package npf...
#     writing package oc...
#     writing package gwfobs_0...
#     writing package riv_0...
# INFORMATION: maxbound in ('gwf6', 'riv', 'dimensions') changed to 400 based on size of stress_period_data
#     writing package obs_0...
#     writing package ghb_0...
# INFORMATION: maxbound in ('gwf6', 'ghb', 'dimensions') changed to 99 based on size of stress_period_data
# FloPy is using the following executable to run the model: ..\..\..\..\..\..\Program Files\Groundwater Vistas\mf6.exe
#                                    MODFLOW 6
#                 U.S. GEOLOGICAL SURVEY MODULAR HYDROLOGIC MODEL
#                             VERSION 6.6.0 12/19/2024
#
#    MODFLOW 6 compiled Dec 19 2024 21:59:25 with Intel(R) Fortran Intel(R) 64
#    Compiler Classic for applications running on Intel(R) 64, Version 2021.7.0
#                              Build 20220726_000000
#
# This software has been approved for release by the U.S. Geological
# Survey (USGS). Although the software has been subjected to rigorous
# review, the USGS reserves the right to update the software as needed
# pursuant to further analysis and review. No warranty, expressed or
# implied, is made by the USGS or the U.S. Government as to the
# functionality of the software and related material nor shall the
# fact of release constitute any such warranty. Furthermore, the
# software is released on condition that neither the USGS nor the U.S.
# Government shall be held liable for any damages resulting from its
# authorized or unauthorized use. Also refer to the USGS Water
# Resources Software User Rights Notice for complete use, copyright,
# and distribution information.
#
#
#  MODFLOW runs in SEQUENTIAL mode
#
#  Run start date and time (yyyy/mm/dd hh:mm:ss): 2025/04/10  6:59:47
#
#  Writing simulation list file: mfsim.lst
#  Using Simulation name file: mfsim.nam
#
#     Solving:  Stress period:     1    Time step:     1
#
#  Run end date and time (yyyy/mm/dd hh:mm:ss): 2025/04/10  6:59:50
#  Elapsed run time:  3.011 Seconds
#
#  Normal termination of simulation.
# 2025-04-10 06:59:51.489470 starting: opening PstFrom.log for logging
# 2025-04-10 06:59:51.489863 starting PstFrom process
# 2025-04-10 06:59:51.491495 starting: setting up dirs
# 2025-04-10 06:59:51.491694 starting: copying original_d 'C:\Users\farnut1\Desktop\How-Many-Realizations-main\Scenario_Notebook\run' to new_d 'C:\Users\farnut1\Desktop\How-Many-Realizations-main\Scenario_Notebook\run\template_d'
# 2025-04-10 06:59:51.538595 finished: copying original_d 'C:\Users\farnut1\Desktop\How-Many-Realizations-main\Scenario_Notebook\run' to new_d 'C:\Users\farnut1\Desktop\How-Many-Realizations-main\Scenario_Notebook\run\template_d' took: 0:00:00.046901
# 2025-04-10 06:59:51.539131 finished: setting up dirs took: 0:00:00.047636
# 2025-04-10 06:59:51.635029 starting: adding observations from output file head_obs.csv
# 2025-04-10 06:59:51.635087 starting: adding observations from tabular output file '['head_obs.csv']'
# 2025-04-10 06:59:51.635161 starting: reading list-style file: C:\Users\farnut1\Desktop\How-Many-Realizations-main\Scenario_Notebook\run\template_d\head_obs.csv
# 2025-04-10 06:59:51.636894 finished: reading list-style file: C:\Users\farnut1\Desktop\How-Many-Realizations-main\Scenario_Notebook\run\template_d\head_obs.csv took: 0:00:00.001733
# 2025-04-10 06:59:51.638051 starting: building insfile for tabular output file head_obs.csv
# 2025-04-10 06:59:51.641235 finished: building insfile for tabular output file head_obs.csv took: 0:00:00.003184
# 2025-04-10 06:59:51.641348 starting: adding observation from instruction file 'C:\Users\farnut1\Desktop\How-Many-Realizations-main\Scenario_Notebook\run\template_d\head_obs.csv.ins'
# 2025-04-10 06:59:51.644233 finished: adding observation from instruction file 'C:\Users\farnut1\Desktop\How-Many-Realizations-main\Scenario_Notebook\run\template_d\head_obs.csv.ins' took: 0:00:00.002885
# 2025-04-10 06:59:51.644834 finished: adding observations from tabular output file '['head_obs.csv']' took: 0:00:00.009747
# 2025-04-10 06:59:51.644894 finished: adding observations from output file head_obs.csv took: 0:00:00.009865
# 2025-04-10 06:59:51.645570 starting: adding observations from output file riv_obs.csv
# 2025-04-10 06:59:51.645609 starting: adding observations from tabular output file '['riv_obs.csv']'
# 2025-04-10 06:59:51.645678 starting: reading list-style file: C:\Users\farnut1\Desktop\How-Many-Realizations-main\Scenario_Notebook\run\template_d\riv_obs.csv
# 2025-04-10 06:59:51.646329 finished: reading list-style file: C:\Users\farnut1\Desktop\How-Many-Realizations-main\Scenario_Notebook\run\template_d\riv_obs.csv took: 0:00:00.000651
# 2025-04-10 06:59:51.646603 starting: building insfile for tabular output file riv_obs.csv
# 2025-04-10 06:59:51.648645 finished: building insfile for tabular output file riv_obs.csv took: 0:00:00.002042
# 2025-04-10 06:59:51.648751 starting: adding observation from instruction file 'C:\Users\farnut1\Desktop\How-Many-Realizations-main\Scenario_Notebook\run\template_d\riv_obs.csv.ins'
# 2025-04-10 06:59:51.650591 finished: adding observation from instruction file 'C:\Users\farnut1\Desktop\How-Many-Realizations-main\Scenario_Notebook\run\template_d\riv_obs.csv.ins' took: 0:00:00.001840
# 2025-04-10 06:59:51.650894 finished: adding observations from tabular output file '['riv_obs.csv']' took: 0:00:00.005285
# 2025-04-10 06:59:51.650942 finished: adding observations from output file riv_obs.csv took: 0:00:00.005372
# 2025-04-10 06:59:51.650971 transform was not passed, setting default tranform to 'log'
# 2025-04-10 06:59:51.651036 starting: adding constant type m style parameters for file(s) ['fp_mf6_model.npf_k.txt']
# 2025-04-10 06:59:51.651101 starting: loading array C:\Users\farnut1\Desktop\How-Many-Realizations-main\Scenario_Notebook\run\template_d\fp_mf6_model.npf_k.txt
# 2025-04-10 06:59:51.662888 finished: loading array C:\Users\farnut1\Desktop\How-Many-Realizations-main\Scenario_Notebook\run\template_d\fp_mf6_model.npf_k.txt took: 0:00:00.011787
# 2025-04-10 06:59:51.662920 loaded array 'C:\Users\farnut1\Desktop\How-Many-Realizations-main\Scenario_Notebook\run\fp_mf6_model.npf_k.txt' of shape (400, 200)
# 2025-04-10 06:59:51.691657 starting: writing array-style template file 'C:\Users\farnut1\Desktop\How-Many-Realizations-main\Scenario_Notebook\run\template_d\tpl\kh-mult-constant_inst0_constant.csv.tpl'
# 2025-04-10 06:59:51.691735 starting: writing template file C:\Users\farnut1\Desktop\How-Many-Realizations-main\Scenario_Notebook\run\template_d\tpl\kh-mult-constant_inst0_constant.csv.tpl for ['kh-mult-constant_inst:0']
# 2025-04-10 06:59:51.877762 finished: writing template file C:\Users\farnut1\Desktop\How-Many-Realizations-main\Scenario_Notebook\run\template_d\tpl\kh-mult-constant_inst0_constant.csv.tpl for ['kh-mult-constant_inst:0'] took: 0:00:00.186027
# 2025-04-10 06:59:51.877844 starting: writing array-based template file 'C:\Users\farnut1\Desktop\How-Many-Realizations-main\Scenario_Notebook\run\template_d\tpl\kh-mult-constant_inst0_constant.csv.tpl'
# 2025-04-10 06:59:51.892995 finished: adding constant type m style parameters for file(s) ['fp_mf6_model.npf_k.txt'] took: 0:00:00.241959
# 2025-04-10 06:59:51.893119 transform was not passed, setting default tranform to 'log'
# 2025-04-10 06:59:51.893208 starting: adding pilotpoints type m style parameters for file(s) ['fp_mf6_model.npf_k.txt']
# 2025-04-10 06:59:51.893384 starting: using geostruct:name:struct1,nugget:0.0,structures:
# name:var1,contribution:1.0,a:750.0,anisotropy:1.0,bearing:0.0
#
# 2025-04-10 06:59:51.893560 starting: loading array C:\Users\farnut1\Desktop\How-Many-Realizations-main\Scenario_Notebook\run\template_d\fp_mf6_model.npf_k.txt
# 2025-04-10 06:59:51.907003 finished: loading array C:\Users\farnut1\Desktop\How-Many-Realizations-main\Scenario_Notebook\run\template_d\fp_mf6_model.npf_k.txt took: 0:00:00.013443
# 2025-04-10 06:59:51.907046 loaded array 'C:\Users\farnut1\Desktop\How-Many-Realizations-main\Scenario_Notebook\run\fp_mf6_model.npf_k.txt' of shape (400, 200)
# 2025-04-10 06:59:51.937726 starting: writing array-style template file 'C:\Users\farnut1\Desktop\How-Many-Realizations-main\Scenario_Notebook\run\template_d\tpl\kh-mult-pilotpoints_inst0_pilotpoints.csv.tpl'
# 2025-04-10 06:59:51.937781 starting: setting up pilot point parameters
# 2025-04-10 06:59:51.937883 WARNING: Directly passing 'pp_space' has been deprecated and will eventually be removed, please use pp_options['pp_space'] instead.
# 2025-04-10 06:59:51.937897 WARNING: Directly passing 'use_pp_zones' has been deprecated and will eventually be removed, please use pp_options['use_pp_zones'] instead.
# 2025-04-10 06:59:51.937907 'spatial_reference' not set in pp_options, Setting to default value: [None]
# 2025-04-10 06:59:51.937922 'try_use_ppu' not set in pp_options, Setting to default value: [True]
# 2025-04-10 06:59:51.937933 'num_threads' not set in pp_options, Setting to default value: [10]
# 2025-04-10 06:59:51.937943 'minpts_interp' not set in pp_options, Setting to default value: [1]
# 2025-04-10 06:59:51.937953 'maxpts_interp' not set in pp_options, Setting to default value: [20]
# 2025-04-10 06:59:51.937964 'search_radius' not set in pp_options, Setting to default value: [10000000000.0]
# 2025-04-10 06:59:51.937976 'fill_value' not set in pp_options, Setting to default value: [1.0]
# 2025-04-10 06:59:51.937988 'lower_limit' not set in pp_options, Setting to default value: [1e-30]
# 2025-04-10 06:59:51.937999 'upper_limit' not set in pp_options, Setting to default value: [1e+30]
# 2025-04-10 06:59:51.938690 WARNING: `use_ppu` requested but failed to import
# falling back to pyemu pp methods
# 2025-04-10 06:59:51.938707 No spatial reference (containing cell spacing) passed.
# 2025-04-10 06:59:51.938725 OK - using spatial reference in parent object.
# 2025-04-10 06:59:52.386022 800 pilot point parameters created
# 2025-04-10 06:59:52.386386 pilot point 'pargp':k,h,-,m,u,l,t,-,p,i,l,o,t,p,o,i,n,t,s
# 2025-04-10 06:59:52.386428 finished: setting up pilot point parameters took: 0:00:00.448647
# 2025-04-10 06:59:52.426938 starting: calculating factors for pargp=kh-mult-pilotpoints
# 2025-04-10 06:59:52.427056 saving krige variance file:C:\Users\farnut1\Desktop\How-Many-Realizations-main\Scenario_Notebook\run\template_d\kh-mult-pilotpoints_inst0pp.var.dat
# 2025-04-10 06:59:52.427120 saving krige factors file:C:\Users\farnut1\Desktop\How-Many-Realizations-main\Scenario_Notebook\run\template_d\kh-mult-pilotpoints_inst0pp.fac
# starting interp point loop for 80000 points
# starting 0
# starting 1
# starting 2
# starting 3
# starting 4
# starting 5
# starting 6
# starting 7
# starting 8
# starting 9
# took 34.277263 seconds
# 2025-04-10 07:00:29.755954 finished: calculating factors for pargp=kh-mult-pilotpoints took: 0:00:37.329016
# 2025-04-10 07:00:29.756127 starting: writing array-based template file 'C:\Users\farnut1\Desktop\How-Many-Realizations-main\Scenario_Notebook\run\template_d\tpl\kh-mult-pilotpoints_inst0pp.dat.tpl'
# 2025-04-10 07:00:29.756181 saving zone array C:\Users\farnut1\Desktop\How-Many-Realizations-main\Scenario_Notebook\run\template_d\tpl\kh-mult-pilotpoints_inst0pp.dat.zone for tpl file C:\Users\farnut1\Desktop\How-Many-Realizations-main\Scenario_Notebook\run\template_d\tpl\kh-mult-pilotpoints_inst0pp.dat.tpl
# 2025-04-10 07:00:29.773610 finished: adding pilotpoints type m style parameters for file(s) ['fp_mf6_model.npf_k.txt'] took: 0:00:37.880402
# 2025-04-10 07:00:29.804959 transform was not passed, setting default tranform to 'log'
# 2025-04-10 07:00:29.805113 starting: adding constant type m style parameters for file(s) ['fp_mf6_model.rcha_recharge_1.txt']
# 2025-04-10 07:00:29.805194 starting: loading array C:\Users\farnut1\Desktop\How-Many-Realizations-main\Scenario_Notebook\run\template_d\fp_mf6_model.rcha_recharge_1.txt
# 2025-04-10 07:00:29.823888 finished: loading array C:\Users\farnut1\Desktop\How-Many-Realizations-main\Scenario_Notebook\run\template_d\fp_mf6_model.rcha_recharge_1.txt took: 0:00:00.018694
# 2025-04-10 07:00:29.823925 loaded array 'C:\Users\farnut1\Desktop\How-Many-Realizations-main\Scenario_Notebook\run\fp_mf6_model.rcha_recharge_1.txt' of shape (400, 200)
# 2025-04-10 07:00:29.863969 starting: writing array-style template file 'C:\Users\farnut1\Desktop\How-Many-Realizations-main\Scenario_Notebook\run\template_d\tpl\rech-mult-constant_inst0_constant.csv.tpl'
# 2025-04-10 07:00:29.864020 starting: writing template file C:\Users\farnut1\Desktop\How-Many-Realizations-main\Scenario_Notebook\run\template_d\tpl\rech-mult-constant_inst0_constant.csv.tpl for ['rech-mult-constant_inst:0']
# 2025-04-10 07:00:30.044337 finished: writing template file C:\Users\farnut1\Desktop\How-Many-Realizations-main\Scenario_Notebook\run\template_d\tpl\rech-mult-constant_inst0_constant.csv.tpl for ['rech-mult-constant_inst:0'] took: 0:00:00.180317
# 2025-04-10 07:00:30.044563 starting: writing array-based template file 'C:\Users\farnut1\Desktop\How-Many-Realizations-main\Scenario_Notebook\run\template_d\tpl\rech-mult-constant_inst0_constant.csv.tpl'
# 2025-04-10 07:00:30.053954 finished: adding constant type m style parameters for file(s) ['fp_mf6_model.rcha_recharge_1.txt'] took: 0:00:00.248841
# 2025-04-10 07:00:30.054017 transform was not passed, setting default tranform to 'log'
# 2025-04-10 07:00:30.054089 starting: adding constant type m style parameters for file(s) ['fp_mf6_model.riv_stress_period_data_1.txt']
# 2025-04-10 07:00:30.054204 starting: loading list-style C:\Users\farnut1\Desktop\How-Many-Realizations-main\Scenario_Notebook\run\template_d\fp_mf6_model.riv_stress_period_data_1.txt
# 2025-04-10 07:00:30.054307 starting: reading list-style file: C:\Users\farnut1\Desktop\How-Many-Realizations-main\Scenario_Notebook\run\template_d\fp_mf6_model.riv_stress_period_data_1.txt
# 2025-04-10 07:00:30.056505 finished: reading list-style file: C:\Users\farnut1\Desktop\How-Many-Realizations-main\Scenario_Notebook\run\template_d\fp_mf6_model.riv_stress_period_data_1.txt took: 0:00:00.002198
# 2025-04-10 07:00:30.056566 loaded list-style 'C:\Users\farnut1\Desktop\How-Many-Realizations-main\Scenario_Notebook\run\template_d\fp_mf6_model.riv_stress_period_data_1.txt' of shape (400, 7)
# 2025-04-10 07:00:30.062411 finished: loading list-style C:\Users\farnut1\Desktop\How-Many-Realizations-main\Scenario_Notebook\run\template_d\fp_mf6_model.riv_stress_period_data_1.txt took: 0:00:00.008207
# 2025-04-10 07:00:30.062521 starting: writing list-style template file 'C:\Users\farnut1\Desktop\How-Many-Realizations-main\Scenario_Notebook\run\template_d\tpl\rivcond-mult-constant_inst0_constant.csv.tpl'
# 2025-04-10 07:00:30.073718 finished: writing list-style template file 'C:\Users\farnut1\Desktop\How-Many-Realizations-main\Scenario_Notebook\run\template_d\tpl\rivcond-mult-constant_inst0_constant.csv.tpl' took: 0:00:00.011197
# 2025-04-10 07:00:30.075704 finished: adding constant type m style parameters for file(s) ['fp_mf6_model.riv_stress_period_data_1.txt'] took: 0:00:00.021615
# 2025-04-10 07:00:30.075761 transform was not passed, setting default tranform to 'log'
# 2025-04-10 07:00:30.075822 starting: adding grid type m style parameters for file(s) ['fp_mf6_model.wel_stress_period_data_1.txt']
# 2025-04-10 07:00:30.075922 starting: loading list-style C:\Users\farnut1\Desktop\How-Many-Realizations-main\Scenario_Notebook\run\template_d\fp_mf6_model.wel_stress_period_data_1.txt
# 2025-04-10 07:00:30.075999 starting: reading list-style file: C:\Users\farnut1\Desktop\How-Many-Realizations-main\Scenario_Notebook\run\template_d\fp_mf6_model.wel_stress_period_data_1.txt
# 2025-04-10 07:00:30.076911 finished: reading list-style file: C:\Users\farnut1\Desktop\How-Many-Realizations-main\Scenario_Notebook\run\template_d\fp_mf6_model.wel_stress_period_data_1.txt took: 0:00:00.000912
# 2025-04-10 07:00:30.076965 loaded list-style 'C:\Users\farnut1\Desktop\How-Many-Realizations-main\Scenario_Notebook\run\template_d\fp_mf6_model.wel_stress_period_data_1.txt' of shape (6, 4)
# 2025-04-10 07:00:30.078110 finished: loading list-style C:\Users\farnut1\Desktop\How-Many-Realizations-main\Scenario_Notebook\run\template_d\fp_mf6_model.wel_stress_period_data_1.txt took: 0:00:00.002188
# 2025-04-10 07:00:30.078196 starting: writing list-style template file 'C:\Users\farnut1\Desktop\How-Many-Realizations-main\Scenario_Notebook\run\template_d\tpl\wellrate-mult-constant_inst0_grid.csv.tpl'
# 2025-04-10 07:00:30.083676 finished: writing list-style template file 'C:\Users\farnut1\Desktop\How-Many-Realizations-main\Scenario_Notebook\run\template_d\tpl\wellrate-mult-constant_inst0_grid.csv.tpl' took: 0:00:00.005480
# 2025-04-10 07:00:30.085265 finished: adding grid type m style parameters for file(s) ['fp_mf6_model.wel_stress_period_data_1.txt'] took: 0:00:00.009443
# noptmax:0, npar_adj:809, nnz_obs:26
# 2025-04-10 07:00:30.141541 starting: building prior covariance matrix
# 2025-04-10 07:00:30.223912 saving prior covariance matrix to file C:\Users\farnut1\Desktop\How-Many-Realizations-main\Scenario_Notebook\run\template_d\prior_cov.jcb
# 2025-04-10 07:00:30.247623 finished: building prior covariance matrix took: 0:00:00.106082
# 2025-04-10 07:00:30.247742 starting: drawing realizations
# 2025-04-10 07:00:30.248236 starting: spectral simulation for grid-scale pars
# 2025-04-10 07:00:30.248732 finished: spectral simulation for grid-scale pars took: 0:00:00.000496
# 2025-04-10 07:00:30.248765 starting: Drawing 809 non-specsim pars
# building diagonal cov
# processing  name:struct1,nugget:0.0,structures:
# name:var1,contribution:1.0,a:750.0,anisotropy:1.0,bearing:0.0
#
# working on pargroups ['kh-mult-pilotpoints']
# build cov matrix
# done
# getting diag var cov 800
# scaling full cov by diag var cov
# adding remaining parameters to diagonal
# 2025-04-10 07:00:30.403016 finished: Drawing 809 non-specsim pars took: 0:00:00.154251
# 2025-04-10 07:00:30.403094 finished: drawing realizations took: 0:00:00.155352
# noptmax:4, npar_adj:809, nnz_obs:26
# wrote C:\Users\farnut1\Desktop\How-Many-Realizations-main\Scenario_Notebook\run\template_d\fp_mf6_model.pst
# 2025-04-10 07:00:30.430244 forward_run line:pyemu.os_utils.run(r'mf6')
#
# 25
# fp_mf6_model
# loading simulation...
#   loading simulation name file...
#   loading tdis package...
#   loading model gwf6...
#     loading package dis...
#     loading package ic...
#     loading package riv...
#     loading package ghb...
#     loading package wel...
#     loading package rch...
#     loading package npf...
#     loading package oc...
#   loading solution package fp_mf6_model...
# WARNING: Package with name riv_0 already exists. Replacing existing package.
# WARNING: Package with name ghb_0 already exists. Replacing existing package.
# writing simulation...
#   writing simulation name file...
#   writing simulation tdis package...
#   writing solution package fp_mf6_model...
#   writing model fp_mf6_model...
#     writing model name file...
#     writing package dis...
#     writing package ic...
#     writing package wel_0...
#     writing package rcha_0...
#     writing package npf...
#     writing package oc...
#     writing package gwfobs_0...
#     writing package riv_0...
# INFORMATION: maxbound in ('gwf6', 'riv', 'dimensions') changed to 400 based on size of stress_period_data
#     writing package obs_0...
#     writing package ghb_0...
# INFORMATION: maxbound in ('gwf6', 'ghb', 'dimensions') changed to 99 based on size of stress_period_data
# FloPy is using the following executable to run the model: ..\..\..\..\..\..\Program Files\Groundwater Vistas\mf6.exe
#                                    MODFLOW 6
#                 U.S. GEOLOGICAL SURVEY MODULAR HYDROLOGIC MODEL
#                             VERSION 6.6.0 12/19/2024
#
#    MODFLOW 6 compiled Dec 19 2024 21:59:25 with Intel(R) Fortran Intel(R) 64
#    Compiler Classic for applications running on Intel(R) 64, Version 2021.7.0
#                              Build 20220726_000000
#
# This software has been approved for release by the U.S. Geological
# Survey (USGS). Although the software has been subjected to rigorous
# review, the USGS reserves the right to update the software as needed
# pursuant to further analysis and review. No warranty, expressed or
# implied, is made by the USGS or the U.S. Government as to the
# functionality of the software and related material nor shall the
# fact of release constitute any such warranty. Furthermore, the
# software is released on condition that neither the USGS nor the U.S.
# Government shall be held liable for any damages resulting from its
# authorized or unauthorized use. Also refer to the USGS Water
# Resources Software User Rights Notice for complete use, copyright,
# and distribution information.
#
#
#  MODFLOW runs in SEQUENTIAL mode
#
#  Run start date and time (yyyy/mm/dd hh:mm:ss): 2025/04/10  7:05:07
#
#  Writing simulation list file: mfsim.lst
#  Using Simulation name file: mfsim.nam
#
#     Solving:  Stress period:     1    Time step:     1
#
#  Run end date and time (yyyy/mm/dd hh:mm:ss): 2025/04/10  7:05:10
#  Elapsed run time:  2.975 Seconds
#
#  Normal termination of simulation.
# 2025-04-10 07:05:11.935594 starting: opening PstFrom.log for logging
# 2025-04-10 07:05:11.935717 starting PstFrom process
# 2025-04-10 07:05:11.936951 starting: setting up dirs
# 2025-04-10 07:05:11.937106 starting: removing existing new_d 'C:\Users\farnut1\Desktop\How-Many-Realizations-main\Scenario_Notebook\run\template_d'
# 2025-04-10 07:05:11.954204 finished: removing existing new_d 'C:\Users\farnut1\Desktop\How-Many-Realizations-main\Scenario_Notebook\run\template_d' took: 0:00:00.017098
# 2025-04-10 07:05:11.954244 starting: copying original_d 'C:\Users\farnut1\Desktop\How-Many-Realizations-main\Scenario_Notebook\run' to new_d 'C:\Users\farnut1\Desktop\How-Many-Realizations-main\Scenario_Notebook\run\template_d'
# 2025-04-10 07:05:11.996699 finished: copying original_d 'C:\Users\farnut1\Desktop\How-Many-Realizations-main\Scenario_Notebook\run' to new_d 'C:\Users\farnut1\Desktop\How-Many-Realizations-main\Scenario_Notebook\run\template_d' took: 0:00:00.042455
# 2025-04-10 07:05:11.997217 finished: setting up dirs took: 0:00:00.060266
# 2025-04-10 07:05:12.088041 starting: adding observations from output file head_obs.csv
# 2025-04-10 07:05:12.088087 starting: adding observations from tabular output file '['head_obs.csv']'
# 2025-04-10 07:05:12.088157 starting: reading list-style file: C:\Users\farnut1\Desktop\How-Many-Realizations-main\Scenario_Notebook\run\template_d\head_obs.csv
# 2025-04-10 07:05:12.089830 finished: reading list-style file: C:\Users\farnut1\Desktop\How-Many-Realizations-main\Scenario_Notebook\run\template_d\head_obs.csv took: 0:00:00.001673
# 2025-04-10 07:05:12.090968 starting: building insfile for tabular output file head_obs.csv
# 2025-04-10 07:05:12.093101 finished: building insfile for tabular output file head_obs.csv took: 0:00:00.002133
# 2025-04-10 07:05:12.093205 starting: adding observation from instruction file 'C:\Users\farnut1\Desktop\How-Many-Realizations-main\Scenario_Notebook\run\template_d\head_obs.csv.ins'
# 2025-04-10 07:05:12.095170 finished: adding observation from instruction file 'C:\Users\farnut1\Desktop\How-Many-Realizations-main\Scenario_Notebook\run\template_d\head_obs.csv.ins' took: 0:00:00.001965
# 2025-04-10 07:05:12.095511 finished: adding observations from tabular output file '['head_obs.csv']' took: 0:00:00.007424
# 2025-04-10 07:05:12.095562 finished: adding observations from output file head_obs.csv took: 0:00:00.007521
# 2025-04-10 07:05:12.096217 starting: adding observations from output file riv_obs.csv
# 2025-04-10 07:05:12.096257 starting: adding observations from tabular output file '['riv_obs.csv']'
# 2025-04-10 07:05:12.096325 starting: reading list-style file: C:\Users\farnut1\Desktop\How-Many-Realizations-main\Scenario_Notebook\run\template_d\riv_obs.csv
# 2025-04-10 07:05:12.096961 finished: reading list-style file: C:\Users\farnut1\Desktop\How-Many-Realizations-main\Scenario_Notebook\run\template_d\riv_obs.csv took: 0:00:00.000636
# 2025-04-10 07:05:12.097212 starting: building insfile for tabular output file riv_obs.csv
# 2025-04-10 07:05:12.099168 finished: building insfile for tabular output file riv_obs.csv took: 0:00:00.001956
# 2025-04-10 07:05:12.099270 starting: adding observation from instruction file 'C:\Users\farnut1\Desktop\How-Many-Realizations-main\Scenario_Notebook\run\template_d\riv_obs.csv.ins'
# 2025-04-10 07:05:12.101059 finished: adding observation from instruction file 'C:\Users\farnut1\Desktop\How-Many-Realizations-main\Scenario_Notebook\run\template_d\riv_obs.csv.ins' took: 0:00:00.001789
# 2025-04-10 07:05:12.101364 finished: adding observations from tabular output file '['riv_obs.csv']' took: 0:00:00.005107
# 2025-04-10 07:05:12.101417 finished: adding observations from output file riv_obs.csv took: 0:00:00.005200
# 2025-04-10 07:05:12.101447 transform was not passed, setting default tranform to 'log'
# 2025-04-10 07:05:12.101506 starting: adding constant type m style parameters for file(s) ['fp_mf6_model.npf_k.txt']
# 2025-04-10 07:05:12.101567 starting: loading array C:\Users\farnut1\Desktop\How-Many-Realizations-main\Scenario_Notebook\run\template_d\fp_mf6_model.npf_k.txt
# 2025-04-10 07:05:12.113816 finished: loading array C:\Users\farnut1\Desktop\How-Many-Realizations-main\Scenario_Notebook\run\template_d\fp_mf6_model.npf_k.txt took: 0:00:00.012249
# 2025-04-10 07:05:12.113847 loaded array 'C:\Users\farnut1\Desktop\How-Many-Realizations-main\Scenario_Notebook\run\fp_mf6_model.npf_k.txt' of shape (400, 200)
# 2025-04-10 07:05:12.147079 starting: writing array-style template file 'C:\Users\farnut1\Desktop\How-Many-Realizations-main\Scenario_Notebook\run\template_d\tpl\kh-mult-constant_inst0_constant.csv.tpl'
# 2025-04-10 07:05:12.147361 starting: writing template file C:\Users\farnut1\Desktop\How-Many-Realizations-main\Scenario_Notebook\run\template_d\tpl\kh-mult-constant_inst0_constant.csv.tpl for ['kh-mult-constant_inst:0']
# 2025-04-10 07:05:12.328550 finished: writing template file C:\Users\farnut1\Desktop\How-Many-Realizations-main\Scenario_Notebook\run\template_d\tpl\kh-mult-constant_inst0_constant.csv.tpl for ['kh-mult-constant_inst:0'] took: 0:00:00.181189
# 2025-04-10 07:05:12.328610 starting: writing array-based template file 'C:\Users\farnut1\Desktop\How-Many-Realizations-main\Scenario_Notebook\run\template_d\tpl\kh-mult-constant_inst0_constant.csv.tpl'
# 2025-04-10 07:05:12.338889 finished: adding constant type m style parameters for file(s) ['fp_mf6_model.npf_k.txt'] took: 0:00:00.237383
# 2025-04-10 07:05:12.338987 transform was not passed, setting default tranform to 'log'
# 2025-04-10 07:05:12.339065 starting: adding pilotpoints type m style parameters for file(s) ['fp_mf6_model.npf_k.txt']
# 2025-04-10 07:05:12.339096 starting: using geostruct:name:struct1,nugget:0.0,structures:
# name:var1,contribution:1.0,a:750.0,anisotropy:1.0,bearing:0.0
#
# 2025-04-10 07:05:12.339158 starting: loading array C:\Users\farnut1\Desktop\How-Many-Realizations-main\Scenario_Notebook\run\template_d\fp_mf6_model.npf_k.txt
# 2025-04-10 07:05:12.351004 finished: loading array C:\Users\farnut1\Desktop\How-Many-Realizations-main\Scenario_Notebook\run\template_d\fp_mf6_model.npf_k.txt took: 0:00:00.011846
# 2025-04-10 07:05:12.351046 loaded array 'C:\Users\farnut1\Desktop\How-Many-Realizations-main\Scenario_Notebook\run\fp_mf6_model.npf_k.txt' of shape (400, 200)
# 2025-04-10 07:05:12.379444 starting: writing array-style template file 'C:\Users\farnut1\Desktop\How-Many-Realizations-main\Scenario_Notebook\run\template_d\tpl\kh-mult-pilotpoints_inst0_pilotpoints.csv.tpl'
# 2025-04-10 07:05:12.379638 starting: setting up pilot point parameters
# 2025-04-10 07:05:12.379738 WARNING: Directly passing 'pp_space' has been deprecated and will eventually be removed, please use pp_options['pp_space'] instead.
# 2025-04-10 07:05:12.379753 WARNING: Directly passing 'use_pp_zones' has been deprecated and will eventually be removed, please use pp_options['use_pp_zones'] instead.
# 2025-04-10 07:05:12.379761 'spatial_reference' not set in pp_options, Setting to default value: [None]
# 2025-04-10 07:05:12.379776 'try_use_ppu' not set in pp_options, Setting to default value: [True]
# 2025-04-10 07:05:12.379786 'num_threads' not set in pp_options, Setting to default value: [10]
# 2025-04-10 07:05:12.379796 'minpts_interp' not set in pp_options, Setting to default value: [1]
# 2025-04-10 07:05:12.379806 'maxpts_interp' not set in pp_options, Setting to default value: [20]
# 2025-04-10 07:05:12.379823 'search_radius' not set in pp_options, Setting to default value: [10000000000.0]
# 2025-04-10 07:05:12.379833 'fill_value' not set in pp_options, Setting to default value: [1.0]
# 2025-04-10 07:05:12.379845 'lower_limit' not set in pp_options, Setting to default value: [1e-30]
# 2025-04-10 07:05:12.379855 'upper_limit' not set in pp_options, Setting to default value: [1e+30]
# 2025-04-10 07:05:12.380560 WARNING: `use_ppu` requested but failed to import
# falling back to pyemu pp methods
# 2025-04-10 07:05:12.380578 No spatial reference (containing cell spacing) passed.
# 2025-04-10 07:05:12.380598 OK - using spatial reference in parent object.
# 2025-04-10 07:05:12.815164 800 pilot point parameters created
# 2025-04-10 07:05:12.815424 pilot point 'pargp':k,h,-,m,u,l,t,-,p,i,l,o,t,p,o,i,n,t,s
# 2025-04-10 07:05:12.815452 finished: setting up pilot point parameters took: 0:00:00.435814
# 2025-04-10 07:05:12.854749 starting: calculating factors for pargp=kh-mult-pilotpoints
# 2025-04-10 07:05:12.854863 saving krige variance file:C:\Users\farnut1\Desktop\How-Many-Realizations-main\Scenario_Notebook\run\template_d\kh-mult-pilotpoints_inst0pp.var.dat
# 2025-04-10 07:05:12.854883 saving krige factors file:C:\Users\farnut1\Desktop\How-Many-Realizations-main\Scenario_Notebook\run\template_d\kh-mult-pilotpoints_inst0pp.fac
# starting interp point loop for 80000 points
# starting 0
# starting 1
# starting 2
# starting 3
# starting 4
# starting 5
# starting 6
# starting 7
# starting 8
# starting 9
# took 33.612892 seconds
# 2025-04-10 07:05:49.467878 finished: calculating factors for pargp=kh-mult-pilotpoints took: 0:00:36.613129
# 2025-04-10 07:05:49.468055 starting: writing array-based template file 'C:\Users\farnut1\Desktop\How-Many-Realizations-main\Scenario_Notebook\run\template_d\tpl\kh-mult-pilotpoints_inst0pp.dat.tpl'
# 2025-04-10 07:05:49.468107 saving zone array C:\Users\farnut1\Desktop\How-Many-Realizations-main\Scenario_Notebook\run\template_d\tpl\kh-mult-pilotpoints_inst0pp.dat.zone for tpl file C:\Users\farnut1\Desktop\How-Many-Realizations-main\Scenario_Notebook\run\template_d\tpl\kh-mult-pilotpoints_inst0pp.dat.tpl
# 2025-04-10 07:05:49.482549 finished: adding pilotpoints type m style parameters for file(s) ['fp_mf6_model.npf_k.txt'] took: 0:00:37.143484
# 2025-04-10 07:05:49.508516 transform was not passed, setting default tranform to 'log'
# 2025-04-10 07:05:49.508662 starting: adding constant type m style parameters for file(s) ['fp_mf6_model.rcha_recharge_1.txt']
# 2025-04-10 07:05:49.508740 starting: loading array C:\Users\farnut1\Desktop\How-Many-Realizations-main\Scenario_Notebook\run\template_d\fp_mf6_model.rcha_recharge_1.txt
# 2025-04-10 07:05:49.527794 finished: loading array C:\Users\farnut1\Desktop\How-Many-Realizations-main\Scenario_Notebook\run\template_d\fp_mf6_model.rcha_recharge_1.txt took: 0:00:00.019054
# 2025-04-10 07:05:49.527843 loaded array 'C:\Users\farnut1\Desktop\How-Many-Realizations-main\Scenario_Notebook\run\fp_mf6_model.rcha_recharge_1.txt' of shape (400, 200)
# 2025-04-10 07:05:49.568809 starting: writing array-style template file 'C:\Users\farnut1\Desktop\How-Many-Realizations-main\Scenario_Notebook\run\template_d\tpl\rech-mult-constant_inst0_constant.csv.tpl'
# 2025-04-10 07:05:49.568884 starting: writing template file C:\Users\farnut1\Desktop\How-Many-Realizations-main\Scenario_Notebook\run\template_d\tpl\rech-mult-constant_inst0_constant.csv.tpl for ['rech-mult-constant_inst:0']
# 2025-04-10 07:05:49.753057 finished: writing template file C:\Users\farnut1\Desktop\How-Many-Realizations-main\Scenario_Notebook\run\template_d\tpl\rech-mult-constant_inst0_constant.csv.tpl for ['rech-mult-constant_inst:0'] took: 0:00:00.184173
# 2025-04-10 07:05:49.753167 starting: writing array-based template file 'C:\Users\farnut1\Desktop\How-Many-Realizations-main\Scenario_Notebook\run\template_d\tpl\rech-mult-constant_inst0_constant.csv.tpl'
# 2025-04-10 07:05:49.764288 finished: adding constant type m style parameters for file(s) ['fp_mf6_model.rcha_recharge_1.txt'] took: 0:00:00.255626
# 2025-04-10 07:05:49.764366 transform was not passed, setting default tranform to 'log'
# 2025-04-10 07:05:49.764441 starting: adding constant type m style parameters for file(s) ['fp_mf6_model.riv_stress_period_data_1.txt']
# 2025-04-10 07:05:49.764548 starting: loading list-style C:\Users\farnut1\Desktop\How-Many-Realizations-main\Scenario_Notebook\run\template_d\fp_mf6_model.riv_stress_period_data_1.txt
# 2025-04-10 07:05:49.764647 starting: reading list-style file: C:\Users\farnut1\Desktop\How-Many-Realizations-main\Scenario_Notebook\run\template_d\fp_mf6_model.riv_stress_period_data_1.txt
# 2025-04-10 07:05:49.766823 finished: reading list-style file: C:\Users\farnut1\Desktop\How-Many-Realizations-main\Scenario_Notebook\run\template_d\fp_mf6_model.riv_stress_period_data_1.txt took: 0:00:00.002176
# 2025-04-10 07:05:49.766891 loaded list-style 'C:\Users\farnut1\Desktop\How-Many-Realizations-main\Scenario_Notebook\run\template_d\fp_mf6_model.riv_stress_period_data_1.txt' of shape (400, 7)
# 2025-04-10 07:05:49.771968 finished: loading list-style C:\Users\farnut1\Desktop\How-Many-Realizations-main\Scenario_Notebook\run\template_d\fp_mf6_model.riv_stress_period_data_1.txt took: 0:00:00.007420
# 2025-04-10 07:05:49.772077 starting: writing list-style template file 'C:\Users\farnut1\Desktop\How-Many-Realizations-main\Scenario_Notebook\run\template_d\tpl\rivcond-mult-constant_inst0_constant.csv.tpl'
# 2025-04-10 07:05:49.781055 finished: writing list-style template file 'C:\Users\farnut1\Desktop\How-Many-Realizations-main\Scenario_Notebook\run\template_d\tpl\rivcond-mult-constant_inst0_constant.csv.tpl' took: 0:00:00.008978
# 2025-04-10 07:05:49.782937 finished: adding constant type m style parameters for file(s) ['fp_mf6_model.riv_stress_period_data_1.txt'] took: 0:00:00.018496
# 2025-04-10 07:05:49.782991 transform was not passed, setting default tranform to 'log'
# 2025-04-10 07:05:49.783056 starting: adding grid type m style parameters for file(s) ['fp_mf6_model.wel_stress_period_data_1.txt']
# 2025-04-10 07:05:49.783160 starting: loading list-style C:\Users\farnut1\Desktop\How-Many-Realizations-main\Scenario_Notebook\run\template_d\fp_mf6_model.wel_stress_period_data_1.txt
# 2025-04-10 07:05:49.783238 starting: reading list-style file: C:\Users\farnut1\Desktop\How-Many-Realizations-main\Scenario_Notebook\run\template_d\fp_mf6_model.wel_stress_period_data_1.txt
# 2025-04-10 07:05:49.784180 finished: reading list-style file: C:\Users\farnut1\Desktop\How-Many-Realizations-main\Scenario_Notebook\run\template_d\fp_mf6_model.wel_stress_period_data_1.txt took: 0:00:00.000942
# 2025-04-10 07:05:49.784235 loaded list-style 'C:\Users\farnut1\Desktop\How-Many-Realizations-main\Scenario_Notebook\run\template_d\fp_mf6_model.wel_stress_period_data_1.txt' of shape (6, 4)
# 2025-04-10 07:05:49.785667 finished: loading list-style C:\Users\farnut1\Desktop\How-Many-Realizations-main\Scenario_Notebook\run\template_d\fp_mf6_model.wel_stress_period_data_1.txt took: 0:00:00.002507
# 2025-04-10 07:05:49.785758 starting: writing list-style template file 'C:\Users\farnut1\Desktop\How-Many-Realizations-main\Scenario_Notebook\run\template_d\tpl\wellrate-mult-constant_inst0_grid.csv.tpl'
# 2025-04-10 07:05:49.792193 finished: writing list-style template file 'C:\Users\farnut1\Desktop\How-Many-Realizations-main\Scenario_Notebook\run\template_d\tpl\wellrate-mult-constant_inst0_grid.csv.tpl' took: 0:00:00.006435
# 2025-04-10 07:05:49.793903 finished: adding grid type m style parameters for file(s) ['fp_mf6_model.wel_stress_period_data_1.txt'] took: 0:00:00.010847
# noptmax:0, npar_adj:809, nnz_obs:26
# 2025-04-10 07:05:49.840040 starting: building prior covariance matrix
# 2025-04-10 07:05:49.924318 saving prior covariance matrix to file C:\Users\farnut1\Desktop\How-Many-Realizations-main\Scenario_Notebook\run\template_d\prior_cov.jcb
# 2025-04-10 07:05:49.946235 finished: building prior covariance matrix took: 0:00:00.106195
# 2025-04-10 07:05:49.946692 starting: drawing realizations
# 2025-04-10 07:05:49.947134 starting: spectral simulation for grid-scale pars
# 2025-04-10 07:05:49.947637 finished: spectral simulation for grid-scale pars took: 0:00:00.000503
# 2025-04-10 07:05:49.947669 starting: Drawing 809 non-specsim pars
# building diagonal cov
# processing  name:struct1,nugget:0.0,structures:
# name:var1,contribution:1.0,a:750.0,anisotropy:1.0,bearing:0.0
#
# working on pargroups ['kh-mult-pilotpoints']
# build cov matrix
# done
# getting diag var cov 800
# scaling full cov by diag var cov
# adding remaining parameters to diagonal
# 2025-04-10 07:05:50.093588 finished: Drawing 809 non-specsim pars took: 0:00:00.145919
# 2025-04-10 07:05:50.093670 finished: drawing realizations took: 0:00:00.146978
# noptmax:4, npar_adj:809, nnz_obs:26
# wrote C:\Users\farnut1\Desktop\How-Many-Realizations-main\Scenario_Notebook\run\template_d\fp_mf6_model.pst
# 2025-04-10 07:05:50.121738 forward_run line:pyemu.os_utils.run(r'mf6')
#
# 50
# fp_mf6_model
# loading simulation...
#   loading simulation name file...
#   loading tdis package...
#   loading model gwf6...
#     loading package dis...
#     loading package ic...
#     loading package riv...
#     loading package ghb...
#     loading package wel...
#     loading package rch...
#     loading package npf...
#     loading package oc...
#   loading solution package fp_mf6_model...
# WARNING: Package with name riv_0 already exists. Replacing existing package.
# WARNING: Package with name ghb_0 already exists. Replacing existing package.
# writing simulation...
#   writing simulation name file...
#   writing simulation tdis package...
#   writing solution package fp_mf6_model...
#   writing model fp_mf6_model...
#     writing model name file...
#     writing package dis...
#     writing package ic...
#     writing package wel_0...
#     writing package rcha_0...
#     writing package npf...
#     writing package oc...
#     writing package gwfobs_0...
#     writing package riv_0...
# INFORMATION: maxbound in ('gwf6', 'riv', 'dimensions') changed to 400 based on size of stress_period_data
#     writing package obs_0...
#     writing package ghb_0...
# INFORMATION: maxbound in ('gwf6', 'ghb', 'dimensions') changed to 99 based on size of stress_period_data
# FloPy is using the following executable to run the model: ..\..\..\..\..\..\Program Files\Groundwater Vistas\mf6.exe
#                                    MODFLOW 6
#                 U.S. GEOLOGICAL SURVEY MODULAR HYDROLOGIC MODEL
#                             VERSION 6.6.0 12/19/2024
#
#    MODFLOW 6 compiled Dec 19 2024 21:59:25 with Intel(R) Fortran Intel(R) 64
#    Compiler Classic for applications running on Intel(R) 64, Version 2021.7.0
#                              Build 20220726_000000
#
# This software has been approved for release by the U.S. Geological
# Survey (USGS). Although the software has been subjected to rigorous
# review, the USGS reserves the right to update the software as needed
# pursuant to further analysis and review. No warranty, expressed or
# implied, is made by the USGS or the U.S. Government as to the
# functionality of the software and related material nor shall the
# fact of release constitute any such warranty. Furthermore, the
# software is released on condition that neither the USGS nor the U.S.
# Government shall be held liable for any damages resulting from its
# authorized or unauthorized use. Also refer to the USGS Water
# Resources Software User Rights Notice for complete use, copyright,
# and distribution information.
#
#
#  MODFLOW runs in SEQUENTIAL mode
#
#  Run start date and time (yyyy/mm/dd hh:mm:ss): 2025/04/10  7:11:49
#
#  Writing simulation list file: mfsim.lst
#  Using Simulation name file: mfsim.nam
#
#     Solving:  Stress period:     1    Time step:     1
#
#  Run end date and time (yyyy/mm/dd hh:mm:ss): 2025/04/10  7:11:52
#  Elapsed run time:  3.000 Seconds
#
#  Normal termination of simulation.
# 2025-04-10 07:11:53.835235 starting: opening PstFrom.log for logging
# 2025-04-10 07:11:53.835506 starting PstFrom process
# 2025-04-10 07:11:53.836840 starting: setting up dirs
# 2025-04-10 07:11:53.836996 starting: removing existing new_d 'C:\Users\farnut1\Desktop\How-Many-Realizations-main\Scenario_Notebook\run\template_d'
# 2025-04-10 07:11:53.857595 finished: removing existing new_d 'C:\Users\farnut1\Desktop\How-Many-Realizations-main\Scenario_Notebook\run\template_d' took: 0:00:00.020599
# 2025-04-10 07:11:53.857638 starting: copying original_d 'C:\Users\farnut1\Desktop\How-Many-Realizations-main\Scenario_Notebook\run' to new_d 'C:\Users\farnut1\Desktop\How-Many-Realizations-main\Scenario_Notebook\run\template_d'
# 2025-04-10 07:11:53.900529 finished: copying original_d 'C:\Users\farnut1\Desktop\How-Many-Realizations-main\Scenario_Notebook\run' to new_d 'C:\Users\farnut1\Desktop\How-Many-Realizations-main\Scenario_Notebook\run\template_d' took: 0:00:00.042891
# 2025-04-10 07:11:53.901043 finished: setting up dirs took: 0:00:00.064203
# 2025-04-10 07:11:53.993658 starting: adding observations from output file head_obs.csv
# 2025-04-10 07:11:53.993712 starting: adding observations from tabular output file '['head_obs.csv']'
# 2025-04-10 07:11:53.993784 starting: reading list-style file: C:\Users\farnut1\Desktop\How-Many-Realizations-main\Scenario_Notebook\run\template_d\head_obs.csv
# 2025-04-10 07:11:53.995557 finished: reading list-style file: C:\Users\farnut1\Desktop\How-Many-Realizations-main\Scenario_Notebook\run\template_d\head_obs.csv took: 0:00:00.001773
# 2025-04-10 07:11:53.996716 starting: building insfile for tabular output file head_obs.csv
# 2025-04-10 07:11:53.998962 finished: building insfile for tabular output file head_obs.csv took: 0:00:00.002246
# 2025-04-10 07:11:53.999143 starting: adding observation from instruction file 'C:\Users\farnut1\Desktop\How-Many-Realizations-main\Scenario_Notebook\run\template_d\head_obs.csv.ins'
# 2025-04-10 07:11:54.001298 finished: adding observation from instruction file 'C:\Users\farnut1\Desktop\How-Many-Realizations-main\Scenario_Notebook\run\template_d\head_obs.csv.ins' took: 0:00:00.002155
# 2025-04-10 07:11:54.001637 finished: adding observations from tabular output file '['head_obs.csv']' took: 0:00:00.007925
# 2025-04-10 07:11:54.001688 finished: adding observations from output file head_obs.csv took: 0:00:00.008030
# 2025-04-10 07:11:54.002377 starting: adding observations from output file riv_obs.csv
# 2025-04-10 07:11:54.002417 starting: adding observations from tabular output file '['riv_obs.csv']'
# 2025-04-10 07:11:54.002486 starting: reading list-style file: C:\Users\farnut1\Desktop\How-Many-Realizations-main\Scenario_Notebook\run\template_d\riv_obs.csv
# 2025-04-10 07:11:54.003153 finished: reading list-style file: C:\Users\farnut1\Desktop\How-Many-Realizations-main\Scenario_Notebook\run\template_d\riv_obs.csv took: 0:00:00.000667
# 2025-04-10 07:11:54.003421 starting: building insfile for tabular output file riv_obs.csv
# 2025-04-10 07:11:54.005576 finished: building insfile for tabular output file riv_obs.csv took: 0:00:00.002155
# 2025-04-10 07:11:54.005686 starting: adding observation from instruction file 'C:\Users\farnut1\Desktop\How-Many-Realizations-main\Scenario_Notebook\run\template_d\riv_obs.csv.ins'
# 2025-04-10 07:11:54.007501 finished: adding observation from instruction file 'C:\Users\farnut1\Desktop\How-Many-Realizations-main\Scenario_Notebook\run\template_d\riv_obs.csv.ins' took: 0:00:00.001815
# 2025-04-10 07:11:54.007804 finished: adding observations from tabular output file '['riv_obs.csv']' took: 0:00:00.005387
# 2025-04-10 07:11:54.007855 finished: adding observations from output file riv_obs.csv took: 0:00:00.005478
# 2025-04-10 07:11:54.007885 transform was not passed, setting default tranform to 'log'
# 2025-04-10 07:11:54.007945 starting: adding constant type m style parameters for file(s) ['fp_mf6_model.npf_k.txt']
# 2025-04-10 07:11:54.008008 starting: loading array C:\Users\farnut1\Desktop\How-Many-Realizations-main\Scenario_Notebook\run\template_d\fp_mf6_model.npf_k.txt
# 2025-04-10 07:11:54.020375 finished: loading array C:\Users\farnut1\Desktop\How-Many-Realizations-main\Scenario_Notebook\run\template_d\fp_mf6_model.npf_k.txt took: 0:00:00.012367
# 2025-04-10 07:11:54.020408 loaded array 'C:\Users\farnut1\Desktop\How-Many-Realizations-main\Scenario_Notebook\run\fp_mf6_model.npf_k.txt' of shape (400, 200)
# 2025-04-10 07:11:54.049299 starting: writing array-style template file 'C:\Users\farnut1\Desktop\How-Many-Realizations-main\Scenario_Notebook\run\template_d\tpl\kh-mult-constant_inst0_constant.csv.tpl'
# 2025-04-10 07:11:54.049454 starting: writing template file C:\Users\farnut1\Desktop\How-Many-Realizations-main\Scenario_Notebook\run\template_d\tpl\kh-mult-constant_inst0_constant.csv.tpl for ['kh-mult-constant_inst:0']
# 2025-04-10 07:11:54.233578 finished: writing template file C:\Users\farnut1\Desktop\How-Many-Realizations-main\Scenario_Notebook\run\template_d\tpl\kh-mult-constant_inst0_constant.csv.tpl for ['kh-mult-constant_inst:0'] took: 0:00:00.184124
# 2025-04-10 07:11:54.233639 starting: writing array-based template file 'C:\Users\farnut1\Desktop\How-Many-Realizations-main\Scenario_Notebook\run\template_d\tpl\kh-mult-constant_inst0_constant.csv.tpl'
# 2025-04-10 07:11:54.243597 finished: adding constant type m style parameters for file(s) ['fp_mf6_model.npf_k.txt'] took: 0:00:00.235652
# 2025-04-10 07:11:54.243691 transform was not passed, setting default tranform to 'log'
# 2025-04-10 07:11:54.243762 starting: adding pilotpoints type m style parameters for file(s) ['fp_mf6_model.npf_k.txt']
# 2025-04-10 07:11:54.243791 starting: using geostruct:name:struct1,nugget:0.0,structures:
# name:var1,contribution:1.0,a:750.0,anisotropy:1.0,bearing:0.0
#
# 2025-04-10 07:11:54.243853 starting: loading array C:\Users\farnut1\Desktop\How-Many-Realizations-main\Scenario_Notebook\run\template_d\fp_mf6_model.npf_k.txt
# 2025-04-10 07:11:54.255833 finished: loading array C:\Users\farnut1\Desktop\How-Many-Realizations-main\Scenario_Notebook\run\template_d\fp_mf6_model.npf_k.txt took: 0:00:00.011980
# 2025-04-10 07:11:54.255868 loaded array 'C:\Users\farnut1\Desktop\How-Many-Realizations-main\Scenario_Notebook\run\fp_mf6_model.npf_k.txt' of shape (400, 200)
# 2025-04-10 07:11:54.285995 starting: writing array-style template file 'C:\Users\farnut1\Desktop\How-Many-Realizations-main\Scenario_Notebook\run\template_d\tpl\kh-mult-pilotpoints_inst0_pilotpoints.csv.tpl'
# 2025-04-10 07:11:54.286081 starting: setting up pilot point parameters
# 2025-04-10 07:11:54.286266 WARNING: Directly passing 'pp_space' has been deprecated and will eventually be removed, please use pp_options['pp_space'] instead.
# 2025-04-10 07:11:54.286284 WARNING: Directly passing 'use_pp_zones' has been deprecated and will eventually be removed, please use pp_options['use_pp_zones'] instead.
# 2025-04-10 07:11:54.286292 'spatial_reference' not set in pp_options, Setting to default value: [None]
# 2025-04-10 07:11:54.286312 'try_use_ppu' not set in pp_options, Setting to default value: [True]
# ...
# 2025-04-13 02:04:10.458401 finished: removing existing new_d 'C:\Users\farnut1\Desktop\How-Many-Realizations-main\Scenario_Notebook\run\template_d' took: 0:00:00.023069
# 2025-04-13 02:04:10.458442 starting: copying original_d 'C:\Users\farnut1\Desktop\How-Many-Realizations-main\Scenario_Notebook\run' to new_d 'C:\Users\farnut1\Desktop\How-Many-Realizations-main\Scenario_Notebook\run\template_d'
# 2025-04-13 02:04:10.503879 finished: copying original_d 'C:\Users\farnut1\Desktop\How-Many-Realizations-main\Scenario_Notebook\run' to new_d 'C:\Users\farnut1\Desktop\How-Many-Realizations-main\Scenario_Notebook\run\template_d' took: 0:00:00.045437
# 2025-04-13 02:04:10.504383 finished: setting up dirs took: 0:00:00.069218
# 2025-04-13 02:04:10.594467 starting: adding observations from output file head_obs.csv
# 2025-04-13 02:04:10.594511 starting: adding observations from tabular output file '['head_obs.csv']'
# 2025-04-13 02:04:10.594580 starting: reading list-style file: C:\Users\farnut1\Desktop\How-Many-Realizations-main\Scenario_Notebook\run\template_d\head_obs.csv
# 2025-04-13 02:04:10.599377 finished: reading list-style file: C:\Users\farnut1\Desktop\How-Many-Realizations-main\Scenario_Notebook\run\template_d\head_obs.csv took: 0:00:00.004797
# 2025-04-13 02:04:10.602992 starting: building insfile for tabular output file head_obs.csv
# 2025-04-13 02:04:10.605985 finished: building insfile for tabular output file head_obs.csv took: 0:00:00.002993
# 2025-04-13 02:04:10.606171 starting: adding observation from instruction file 'C:\Users\farnut1\Desktop\How-Many-Realizations-main\Scenario_Notebook\run\template_d\head_obs.csv.ins'
# 2025-04-13 02:04:10.608679 finished: adding observation from instruction file 'C:\Users\farnut1\Desktop\How-Many-Realizations-main\Scenario_Notebook\run\template_d\head_obs.csv.ins' took: 0:00:00.002508
# 2025-04-13 02:04:10.609027 finished: adding observations from tabular output file '['head_obs.csv']' took: 0:00:00.014516
# 2025-04-13 02:04:10.609077 finished: adding observations from output file head_obs.csv took: 0:00:00.014610
# 2025-04-13 02:04:10.609743 starting: adding observations from output file riv_obs.csv
# 2025-04-13 02:04:10.609782 starting: adding observations from tabular output file '['riv_obs.csv']'
# 2025-04-13 02:04:10.609848 starting: reading list-style file: C:\Users\farnut1\Desktop\How-Many-Realizations-main\Scenario_Notebook\run\template_d\riv_obs.csv
# 2025-04-13 02:04:10.610502 finished: reading list-style file: C:\Users\farnut1\Desktop\How-Many-Realizations-main\Scenario_Notebook\run\template_d\riv_obs.csv took: 0:00:00.000654
# 2025-04-13 02:04:10.610759 starting: building insfile for tabular output file riv_obs.csv
# 2025-04-13 02:04:10.613092 finished: building insfile for tabular output file riv_obs.csv took: 0:00:00.002333
# 2025-04-13 02:04:10.613269 starting: adding observation from instruction file 'C:\Users\farnut1\Desktop\How-Many-Realizations-main\Scenario_Notebook\run\template_d\riv_obs.csv.ins'
# 2025-04-13 02:04:10.616447 finished: adding observation from instruction file 'C:\Users\farnut1\Desktop\How-Many-Realizations-main\Scenario_Notebook\run\template_d\riv_obs.csv.ins' took: 0:00:00.003178
# 2025-04-13 02:04:10.616974 finished: adding observations from tabular output file '['riv_obs.csv']' took: 0:00:00.007192
# 2025-04-13 02:04:10.617065 finished: adding observations from output file riv_obs.csv took: 0:00:00.007322
# 2025-04-13 02:04:10.617128 transform was not passed, setting default tranform to 'log'
# 2025-04-13 02:04:10.617240 starting: adding constant type m style parameters for file(s) ['fp_mf6_model.npf_k.txt']
# 2025-04-13 02:04:10.617370 starting: loading array C:\Users\farnut1\Desktop\How-Many-Realizations-main\Scenario_Notebook\run\template_d\fp_mf6_model.npf_k.txt
# 2025-04-13 02:04:10.630595 finished: loading array C:\Users\farnut1\Desktop\How-Many-Realizations-main\Scenario_Notebook\run\template_d\fp_mf6_model.npf_k.txt took: 0:00:00.013225
# 2025-04-13 02:04:10.630633 loaded array 'C:\Users\farnut1\Desktop\How-Many-Realizations-main\Scenario_Notebook\run\fp_mf6_model.npf_k.txt' of shape (400, 200)
# 2025-04-13 02:04:10.659565 starting: writing array-style template file 'C:\Users\farnut1\Desktop\How-Many-Realizations-main\Scenario_Notebook\run\template_d\tpl\kh-mult-constant_inst0_constant.csv.tpl'
# 2025-04-13 02:04:10.659630 starting: writing template file C:\Users\farnut1\Desktop\How-Many-Realizations-main\Scenario_Notebook\run\template_d\tpl\kh-mult-constant_inst0_constant.csv.tpl for ['kh-mult-constant_inst:0']
# 2025-04-13 02:04:10.832245 finished: writing template file C:\Users\farnut1\Desktop\How-Many-Realizations-main\Scenario_Notebook\run\template_d\tpl\kh-mult-constant_inst0_constant.csv.tpl for ['kh-mult-constant_inst:0'] took: 0:00:00.172615
# 2025-04-13 02:04:10.832306 starting: writing array-based template file 'C:\Users\farnut1\Desktop\How-Many-Realizations-main\Scenario_Notebook\run\template_d\tpl\kh-mult-constant_inst0_constant.csv.tpl'
# 2025-04-13 02:04:10.841524 finished: adding constant type m style parameters for file(s) ['fp_mf6_model.npf_k.txt'] took: 0:00:00.224284
# 2025-04-13 02:04:10.841699 transform was not passed, setting default tranform to 'log'
# 2025-04-13 02:04:10.841774 starting: adding pilotpoints type m style parameters for file(s) ['fp_mf6_model.npf_k.txt']
# 2025-04-13 02:04:10.841803 starting: using geostruct:name:struct1,nugget:0.0,structures:
# name:var1,contribution:1.0,a:3750.0,anisotropy:1.0,bearing:0.0
#
# 2025-04-13 02:04:10.841862 starting: loading array C:\Users\farnut1\Desktop\How-Many-Realizations-main\Scenario_Notebook\run\template_d\fp_mf6_model.npf_k.txt
# 2025-04-13 02:04:10.855251 finished: loading array C:\Users\farnut1\Desktop\How-Many-Realizations-main\Scenario_Notebook\run\template_d\fp_mf6_model.npf_k.txt took: 0:00:00.013389
# 2025-04-13 02:04:10.855316 loaded array 'C:\Users\farnut1\Desktop\How-Many-Realizations-main\Scenario_Notebook\run\fp_mf6_model.npf_k.txt' of shape (400, 200)
# 2025-04-13 02:04:10.888296 starting: writing array-style template file 'C:\Users\farnut1\Desktop\How-Many-Realizations-main\Scenario_Notebook\run\template_d\tpl\kh-mult-pilotpoints_inst0_pilotpoints.csv.tpl'
# 2025-04-13 02:04:10.888365 starting: setting up pilot point parameters
# 2025-04-13 02:04:10.888534 WARNING: Directly passing 'pp_space' has been deprecated and will eventually be removed, please use pp_options['pp_space'] instead.
# 2025-04-13 02:04:10.888548 WARNING: Directly passing 'use_pp_zones' has been deprecated and will eventually be removed, please use pp_options['use_pp_zones'] instead.
# 2025-04-13 02:04:10.888556 'spatial_reference' not set in pp_options, Setting to default value: [None]
# 2025-04-13 02:04:10.888573 'try_use_ppu' not set in pp_options, Setting to default value: [True]
# 2025-04-13 02:04:10.888584 'num_threads' not set in pp_options, Setting to default value: [10]
# 2025-04-13 02:04:10.888594 'minpts_interp' not set in pp_options, Setting to default value: [1]
# 2025-04-13 02:04:10.888603 'maxpts_interp' not set in pp_options, Setting to default value: [20]
# 2025-04-13 02:04:10.888615 'search_radius' not set in pp_options, Setting to default value: [10000000000.0]
# 2025-04-13 02:04:10.888625 'fill_value' not set in pp_options, Setting to default value: [1.0]
# 2025-04-13 02:04:10.888637 'lower_limit' not set in pp_options, Setting to default value: [1e-30]
# 2025-04-13 02:04:10.888647 'upper_limit' not set in pp_options, Setting to default value: [1e+30]
# 2025-04-13 02:04:10.889329 WARNING: `use_ppu` requested but failed to import
# falling back to pyemu pp methods
# 2025-04-13 02:04:10.889346 No spatial reference (containing cell spacing) passed.
# 2025-04-13 02:04:10.889366 OK - using spatial reference in parent object.
# 2025-04-13 02:04:10.917532 32 pilot point parameters created
# 2025-04-13 02:04:10.917621 pilot point 'pargp':k,h,-,m,u,l,t,-,p,i,l,o,t,p,o,i,n,t,s
# 2025-04-13 02:04:10.917641 finished: setting up pilot point parameters took: 0:00:00.029276
# 2025-04-13 02:04:10.919708 starting: calculating factors for pargp=kh-mult-pilotpoints
# 2025-04-13 02:04:10.919777 saving krige variance file:C:\Users\farnut1\Desktop\How-Many-Realizations-main\Scenario_Notebook\run\template_d\kh-mult-pilotpoints_inst0pp.var.dat
# 2025-04-13 02:04:10.919800 saving krige factors file:C:\Users\farnut1\Desktop\How-Many-Realizations-main\Scenario_Notebook\run\template_d\kh-mult-pilotpoints_inst0pp.fac
# starting interp point loop for 80000 points
# starting 0
# starting 1
# starting 2
# starting 3
# starting 4
# starting 5
# starting 6
# starting 7
# starting 8
# starting 9
# took 33.733129 seconds
# 2025-04-13 02:04:45.757336 finished: calculating factors for pargp=kh-mult-pilotpoints took: 0:00:34.837628
# 2025-04-13 02:04:45.757527 starting: writing array-based template file 'C:\Users\farnut1\Desktop\How-Many-Realizations-main\Scenario_Notebook\run\template_d\tpl\kh-mult-pilotpoints_inst0pp.dat.tpl'
# 2025-04-13 02:04:45.757820 saving zone array C:\Users\farnut1\Desktop\How-Many-Realizations-main\Scenario_Notebook\run\template_d\tpl\kh-mult-pilotpoints_inst0pp.dat.zone for tpl file C:\Users\farnut1\Desktop\How-Many-Realizations-main\Scenario_Notebook\run\template_d\tpl\kh-mult-pilotpoints_inst0pp.dat.tpl
# 2025-04-13 02:04:45.771924 finished: adding pilotpoints type m style parameters for file(s) ['fp_mf6_model.npf_k.txt'] took: 0:00:34.930150
# 2025-04-13 02:04:45.793896 transform was not passed, setting default tranform to 'log'
# 2025-04-13 02:04:45.794048 starting: adding constant type m style parameters for file(s) ['fp_mf6_model.rcha_recharge_1.txt']
# 2025-04-13 02:04:45.794127 starting: loading array C:\Users\farnut1\Desktop\How-Many-Realizations-main\Scenario_Notebook\run\template_d\fp_mf6_model.rcha_recharge_1.txt
# 2025-04-13 02:04:45.812421 finished: loading array C:\Users\farnut1\Desktop\How-Many-Realizations-main\Scenario_Notebook\run\template_d\fp_mf6_model.rcha_recharge_1.txt took: 0:00:00.018294
# 2025-04-13 02:04:45.812477 loaded array 'C:\Users\farnut1\Desktop\How-Many-Realizations-main\Scenario_Notebook\run\fp_mf6_model.rcha_recharge_1.txt' of shape (400, 200)
# 2025-04-13 02:04:45.853466 starting: writing array-style template file 'C:\Users\farnut1\Desktop\How-Many-Realizations-main\Scenario_Notebook\run\template_d\tpl\rech-mult-constant_inst0_constant.csv.tpl'
# 2025-04-13 02:04:45.853521 starting: writing template file C:\Users\farnut1\Desktop\How-Many-Realizations-main\Scenario_Notebook\run\template_d\tpl\rech-mult-constant_inst0_constant.csv.tpl for ['rech-mult-constant_inst:0']
# 2025-04-13 02:04:46.037968 finished: writing template file C:\Users\farnut1\Desktop\How-Many-Realizations-main\Scenario_Notebook\run\template_d\tpl\rech-mult-constant_inst0_constant.csv.tpl for ['rech-mult-constant_inst:0'] took: 0:00:00.184447
# 2025-04-13 02:04:46.038218 starting: writing array-based template file 'C:\Users\farnut1\Desktop\How-Many-Realizations-main\Scenario_Notebook\run\template_d\tpl\rech-mult-constant_inst0_constant.csv.tpl'
# 2025-04-13 02:04:46.046774 finished: adding constant type m style parameters for file(s) ['fp_mf6_model.rcha_recharge_1.txt'] took: 0:00:00.252726
# 2025-04-13 02:04:46.046845 transform was not passed, setting default tranform to 'log'
# 2025-04-13 02:04:46.046918 starting: adding constant type m style parameters for file(s) ['fp_mf6_model.riv_stress_period_data_1.txt']
# 2025-04-13 02:04:46.047022 starting: loading list-style C:\Users\farnut1\Desktop\How-Many-Realizations-main\Scenario_Notebook\run\template_d\fp_mf6_model.riv_stress_period_data_1.txt
# 2025-04-13 02:04:46.047113 starting: reading list-style file: C:\Users\farnut1\Desktop\How-Many-Realizations-main\Scenario_Notebook\run\template_d\fp_mf6_model.riv_stress_period_data_1.txt
# 2025-04-13 02:04:46.049223 finished: reading list-style file: C:\Users\farnut1\Desktop\How-Many-Realizations-main\Scenario_Notebook\run\template_d\fp_mf6_model.riv_stress_period_data_1.txt took: 0:00:00.002110
# 2025-04-13 02:04:46.049288 loaded list-style 'C:\Users\farnut1\Desktop\How-Many-Realizations-main\Scenario_Notebook\run\template_d\fp_mf6_model.riv_stress_period_data_1.txt' of shape (400, 7)
# 2025-04-13 02:04:46.055192 finished: loading list-style C:\Users\farnut1\Desktop\How-Many-Realizations-main\Scenario_Notebook\run\template_d\fp_mf6_model.riv_stress_period_data_1.txt took: 0:00:00.008170
# 2025-04-13 02:04:46.055302 starting: writing list-style template file 'C:\Users\farnut1\Desktop\How-Many-Realizations-main\Scenario_Notebook\run\template_d\tpl\rivcond-mult-constant_inst0_constant.csv.tpl'
# 2025-04-13 02:04:46.064476 finished: writing list-style template file 'C:\Users\farnut1\Desktop\How-Many-Realizations-main\Scenario_Notebook\run\template_d\tpl\rivcond-mult-constant_inst0_constant.csv.tpl' took: 0:00:00.009174
# 2025-04-13 02:04:46.066259 finished: adding constant type m style parameters for file(s) ['fp_mf6_model.riv_stress_period_data_1.txt'] took: 0:00:00.019341
# 2025-04-13 02:04:46.066313 transform was not passed, setting default tranform to 'log'
# 2025-04-13 02:04:46.066375 starting: adding grid type m style parameters for file(s) ['fp_mf6_model.wel_stress_period_data_1.txt']
# 2025-04-13 02:04:46.066473 starting: loading list-style C:\Users\farnut1\Desktop\How-Many-Realizations-main\Scenario_Notebook\run\template_d\fp_mf6_model.wel_stress_period_data_1.txt
# 2025-04-13 02:04:46.066548 starting: reading list-style file: C:\Users\farnut1\Desktop\How-Many-Realizations-main\Scenario_Notebook\run\template_d\fp_mf6_model.wel_stress_period_data_1.txt
# 2025-04-13 02:04:46.067491 finished: reading list-style file: C:\Users\farnut1\Desktop\How-Many-Realizations-main\Scenario_Notebook\run\template_d\fp_mf6_model.wel_stress_period_data_1.txt took: 0:00:00.000943
# 2025-04-13 02:04:46.067546 loaded list-style 'C:\Users\farnut1\Desktop\How-Many-Realizations-main\Scenario_Notebook\run\template_d\fp_mf6_model.wel_stress_period_data_1.txt' of shape (6, 4)
# 2025-04-13 02:04:46.068711 finished: loading list-style C:\Users\farnut1\Desktop\How-Many-Realizations-main\Scenario_Notebook\run\template_d\fp_mf6_model.wel_stress_period_data_1.txt took: 0:00:00.002238
# 2025-04-13 02:04:46.068798 starting: writing list-style template file 'C:\Users\farnut1\Desktop\How-Many-Realizations-main\Scenario_Notebook\run\template_d\tpl\wellrate-mult-constant_inst0_grid.csv.tpl'
# 2025-04-13 02:04:46.073977 finished: writing list-style template file 'C:\Users\farnut1\Desktop\How-Many-Realizations-main\Scenario_Notebook\run\template_d\tpl\wellrate-mult-constant_inst0_grid.csv.tpl' took: 0:00:00.005179
# 2025-04-13 02:04:46.075579 finished: adding grid type m style parameters for file(s) ['fp_mf6_model.wel_stress_period_data_1.txt'] took: 0:00:00.009204
# noptmax:0, npar_adj:41, nnz_obs:101
# 2025-04-13 02:04:46.109524 starting: building prior covariance matrix
# 2025-04-13 02:04:46.112321 saving prior covariance matrix to file C:\Users\farnut1\Desktop\How-Many-Realizations-main\Scenario_Notebook\run\template_d\prior_cov.jcb
# 2025-04-13 02:04:46.114705 finished: building prior covariance matrix took: 0:00:00.005181
# 2025-04-13 02:04:46.114761 starting: drawing realizations
# 2025-04-13 02:04:46.114963 starting: spectral simulation for grid-scale pars
# 2025-04-13 02:04:46.115312 finished: spectral simulation for grid-scale pars took: 0:00:00.000349
# 2025-04-13 02:04:46.115342 starting: Drawing 41 non-specsim pars
# building diagonal cov
# processing  name:struct1,nugget:0.0,structures:
# name:var1,contribution:1.0,a:3750.0,anisotropy:1.0,bearing:0.0
#
# working on pargroups ['kh-mult-pilotpoints']
# build cov matrix
# done
# getting diag var cov 32
# scaling full cov by diag var cov
# adding remaining parameters to diagonal
# 2025-04-13 02:04:46.131970 finished: Drawing 41 non-specsim pars took: 0:00:00.016628
# 2025-04-13 02:04:46.132012 finished: drawing realizations took: 0:00:00.017251
# noptmax:4, npar_adj:41, nnz_obs:101
# wrote C:\Users\farnut1\Desktop\How-Many-Realizations-main\Scenario_Notebook\run\template_d\fp_mf6_model.pst
# 2025-04-13 02:04:46.163609 forward_run line:pyemu.os_utils.run(r'mf6')
